# %% [markdown]
# Emigrate
# ========
# Emigrate is an electrophoresis simulator written in python. It is based on the the scipy.integrate.ode solver. It is written with multiple simulation modules to allow varying solution schemes in order to allow easy extension.

# %% [markdown]
# First, we'll import emigrate. We'll also import ionize, because it contains the Ion and Solution objects that we will use to set the initial conditions
# We'll also import numpy to set up some vectors, and cProfile for code profiling

# %%
import emigrate
import ionize

import cProfile
import time

# from matplotlib import pyplot as plot
from matplotlib.pyplot import *
# %matplotlib inline

# %% [markdown]
# Getting Started
# -----------------
#
# ### Initial Condition
# To define an initial condition, use the emigrate.Electrolyte class. An Electrolyte represents a quasi-1D system of solutions in a channel. It has a set of nodes, and each node represents a point along the axial dimension. Each point has a concentration for each Ion in the system. It can also have other attributes, such as a cross-sectional area, a pH, and an electric field. Only nodes, ions, and concentrations are mandatory. Other attributes are optional.
#
# The easiest way of initializing an electrolyte is to create a set of solutions, and then creating a

# %%
solutions = [ionize.Solution(['hepes', 'tris'], [.05, .105]),
             ionize.Solution(['caproic acid', 'tris', 'fluorescein', 'alexa fluor 488', 'mops', 'acetic acid'], 
                              [.01, .1, .01, .01, .01, .01]),
             ionize.Solution(['hydrochloric acid', 'tris'], [.04, .08]),
            ]

system = emigrate.Frame(dict(
                         n_nodes=137,
                         lengths=[.005, .001, .02],
                         interface_length=.0005,
                         solutions=solutions,
                         current=-500.,
                         ))

# Plot the electrolyte concentrations.
for i in range(len(system.ions)):
    plot(system.nodes, system.concentrations[i,:], '-o')
xlabel('x (m)')
ylabel('concentration (M)')
xlim([min(system.nodes), max(system.nodes)])
show()

# %% [markdown]
# ### Solving
#
# We solve the solution by using the Migrate class. This class takes the system defined by the Constructor as an input and solves it.

# %%
solver = emigrate.Solver(system, filename='examples/example_1.hdf5', precondition=True, flux_mode='slip')
tmax = 200
dt = 1
ode_solver = 'dopri5'
profile = True

if profile:
    cProfile.run("solver.solve(dt, tmax, method=ode_solver)")
else:
    epoch = time.time()
    solver.solve(dt, tmax, method=ode_solver)
    print 'Solved in {:.2f} seconds.'.format(time.time()-epoch)
# Out:
# Solving...
# Solved.
#          25131355 function calls in 101.230 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  101.230  101.230 <string>:1(<module>)
#    421755    0.620    0.000   14.657    0.000 Differentiate.py:28(first_derivative)
#    168702    0.266    0.000    6.784    0.000 Differentiate.py:32(second_derivative)
#     84351    0.126    0.000    2.099    0.000 Differentiate.py:36(smooth)
#    421755    0.655    0.000   15.313    0.000 Fluxer.py:70(first_derivative)
#    168702    0.287    0.000    7.072    0.000 Fluxer.py:74(second_derivative)
#     84351    0.191    0.000    0.191    0.000 Fluxer.py:78(set_boundary)
#     84351    0.359    0.000   64.763    0.001 Fluxer.py:86(update)
#     84351    0.842    0.000    1.407    0.000 Fluxer.py:99(_impose_nonnegativity)
#       201    0.006    0.000    0.484    0.002 FrameSeries.py:65(add_frame)
#       201    0.098    0.000    0.310    0.002 FrameSeries.py:76(_write_frame)
#     38994    0.257    0.000    0.655    0.000 Multiroot.py:102(_ensure_positive)
#     12998    0.049    0.000   28.662    0.002 Multiroot.py:21(__call__)
#     12998    0.120    0.000   28.613    0.002 Multiroot.py:29(_split_solve)
#     38994    0.171    0.000   28.021    0.001 Multiroot.py:46(_solve)
#     38994    0.463    0.000   27.195    0.001 Multiroot.py:50(_optimize_solve)
#     38994    0.023    0.000    0.023    0.000 Multiroot.py:66(_get_objective)
#    211026    9.702    0.000   11.477    0.000 Multiroot.py:67(objective)
#     38994    0.646    0.000    0.771    0.000 Multiroot.py:73(_get_jacobian)
#     77998    3.403    0.000    4.789    0.000 Multiroot.py:82(jac)
#         3    0.000    0.000    0.001    0.000 Multiroot.py:92(_1d_analytical_solve)
#     84351    1.961    0.000    5.160    0.000 SLIP.py:108(node_cost)
#     84351    0.190    0.000    0.218    0.000 SLIP.py:118(set_Kag)
#     84351    0.424    0.000    9.068    0.000 SLIP.py:124(set_derivatives)
#     84351    2.144    0.000    9.098    0.000 SLIP.py:140(set_E)
#     84351    0.446    0.000    1.202    0.000 SLIP.py:156(conductivity)
#     84351    1.076    0.000    4.264    0.000 SLIP.py:163(diffusive_current)
#     84352    0.178    0.000    0.584    0.000 SLIP.py:172(pack)
#     97548    0.362    0.000    0.526    0.000 SLIP.py:188(unpack)
#     84351    1.253    0.000   62.806    0.001 SLIP.py:22(_update)
#     84351    0.134    0.000    0.261    0.000 SLIP.py:33(set_area_flux)
#     84351    0.892    0.000   10.528    0.000 SLIP.py:40(set_node_flux)
#     84351    1.976    0.000   19.605    0.000 SLIP.py:50(electromigration_dcdt)
#     84351    2.425    0.000   11.566    0.000 SLIP.py:58(diffusion_dcdt)
#     84351    1.427    0.000    1.427    0.000 SLIP.py:66(advection_dcdt)
#     84351    0.759    0.000    0.759    0.000 SLIP.py:72(electromigration_flux)
#     84351    2.226    0.000   11.330    0.000 SLIP.py:79(limit)
#     84351    1.579    0.000    2.797    0.000 SLIP.py:86(set_alpha)
#     84351    1.218    0.000    1.218    0.000 SLIP.py:92(set_characteristic)
#     84351    3.068    0.000    5.054    0.000 SLIP.py:97(limiter)
#       201    0.002    0.000    0.486    0.002 Solver.py:113(_write_solution)
#         1    0.000    0.000  101.230  101.230 Solver.py:117(solve)
#       201    0.001    0.000  101.230    0.504 Solver.py:128(iterate)
#       200    0.002    0.000  101.216    0.506 Solver.py:140(_solve_step)
#         1    0.000    0.000    0.013    0.013 Solver.py:147(_initialize_solver)
#     12997    0.029    0.000   33.875    0.003 Solver.py:164(_solout)
#     84351    0.287    0.000   66.091    0.001 Solver.py:169(_objective)
#     12998    1.305    0.000   30.522    0.002 VariablepH.py:129(_calc_pH)
#     12998    0.184    0.000    0.362    0.000 VariablepH.py:151(_calc_mobility)
#     12998    0.487    0.000    0.650    0.000 VariablepH.py:158(_calc_diffusivity)
#     12998    0.369    0.000    0.524    0.000 VariablepH.py:167(_calc_molar_conductivity)
#     12998    0.799    0.000    1.389    0.000 VariablepH.py:174(_calc_ionization_fraction)
#     12998    0.126    0.000    0.126    0.000 VariablepH.py:187(_calc_water_conductivity)
#     12998    0.114    0.000    0.114    0.000 VariablepH.py:191(_calc_water_diffusive_conductivity)
#     12998    0.101    0.000   33.787    0.003 VariablepH.py:53(equilibrate)
#         4    0.000    0.000    0.000    0.000 __init__.py:193(dumps)
#     84351    0.055    0.000    0.895    0.000 _methods.py:28(_amin)
#    607067    0.312    0.000    4.353    0.000 _methods.py:31(_sum)
#    292047    0.133    0.000    1.059    0.000 _methods.py:37(_any)
#       609    0.000    0.000    0.005    0.000 _methods.py:40(_all)
#       200    0.734    0.004  100.727    0.504 _ode.py:1014(run)
#     12997    0.027    0.000   33.902    0.003 _ode.py:1023(_solout)
#         1    0.000    0.000    0.000    0.000 _ode.py:333(__init__)
#       200    0.000    0.000    0.000    0.000 _ode.py:341(y)
#         1    0.000    0.000    0.000    0.000 _ode.py:345(set_initial_value)
#         1    0.000    0.000    0.001    0.001 _ode.py:357(set_integrator)
#       200    0.001    0.000  100.728    0.504 _ode.py:382(integrate)
#       201    0.000    0.000    0.000    0.000 _ode.py:401(successful)
#         1    0.000    0.000    0.000    0.000 _ode.py:419(set_solout)
#         1    0.000    0.000    0.000    0.000 _ode.py:595(find_integrator)
#         1    0.000    0.000    0.000    0.000 _ode.py:964(__init__)
#         2    0.000    0.000    0.000    0.000 _ode.py:989(set_solout)
#         2    0.000    0.000    0.000    0.000 _ode.py:997(reset)
#     38994    0.234    0.000   25.770    0.001 _root.py:23(root)
#    253053    0.089    0.000    0.089    0.000 arraypad.py:102(<genexpr>)
#     84351    0.306    0.000    0.856    0.000 arraypad.py:1048(_validate_lengths)
#     84351    1.125    0.000    4.454    0.000 arraypad.py:1093(pad)
#    168702    0.359    0.000    0.689    0.000 arraypad.py:112(_append_const)
#    253053    0.067    0.000    0.067    0.000 arraypad.py:136(<genexpr>)
#    168702    0.565    0.000    1.071    0.000 arraypad.py:78(_prepend_const)
#    168702    0.576    0.000    0.895    0.000 arraypad.py:990(_normalize_shape)
#       201    0.000    0.000    0.000    0.000 attrs.py:43(__init__)
#       201    0.003    0.000    0.045    0.000 attrs.py:79(__setitem__)
#       201    0.019    0.000    0.040    0.000 attrs.py:94(create)
#         1    0.000    0.000    0.000    0.000 attrsettr.py:35(__getattr__)
#      1809    0.003    0.000    0.016    0.000 base.py:104(_e)
#      1005    0.012    0.000    0.012    0.000 base.py:114(get_lcpl)
#     20100    0.008    0.000    0.044    0.000 base.py:136(_d)
#      3819    0.001    0.000    0.001    0.000 base.py:230(id)
#    674808    0.727    0.000   11.992    0.000 base.py:233(dot)
#       201    0.002    0.000    0.002    0.000 base.py:256(attrs)
#       804    0.001    0.000    0.001    0.000 base.py:263(__init__)
#    674808    1.544    0.000   11.265    0.000 base.py:282(__mul__)
#       201    0.006    0.000    0.083    0.000 base.py:358(keys)
#       804    0.003    0.000    0.004    0.000 base.py:45(guess_dtype)
#       804    0.000    0.000    0.000    0.000 base.py:92(_lapl)
#   1349616    0.272    0.000    0.272    0.000 base.py:93(get_shape)
#      1005    0.000    0.000    0.000    0.000 base.py:98(_lcpl)
#    421755    1.532    0.000    4.693    0.000 compressed.py:447(_mul_vector)
#    253053    1.303    0.000    4.875    0.000 compressed.py:460(_mul_multivector)
#    674808    0.231    0.000    0.231    0.000 data.py:28(_get_dtype)
#       603    0.020    0.000    0.030    0.000 dataset.py:260(__init__)
#       603    0.069    0.000    0.137    0.000 dataset.py:44(make_new_dset)
#         4    0.000    0.000    0.000    0.000 encoder.py:101(__init__)
#         4    0.000    0.000    0.000    0.000 encoder.py:186(encode)
#         4    0.000    0.000    0.000    0.000 encoder.py:212(iterencode)
#        26    0.000    0.000    0.000    0.000 encoder.py:33(encode_basestring)
#         1    0.000    0.000    0.000    0.000 encoder.py:37(replace)
#       201    0.000    0.000    0.000    0.000 files.py:172(fid)
#       201    0.016    0.000    0.016    0.000 files.py:293(flush)
#       603    0.008    0.000    0.009    0.000 filters.py:211(get_filters)
#       603    0.017    0.000    0.037    0.000 filters.py:257(guess_chunk)
#      1407    0.001    0.000    0.001    0.000 filters.py:267(<genexpr>)
#      1407    0.003    0.000    0.003    0.000 filters.py:307(<genexpr>)
#       603    0.021    0.000    0.058    0.000 filters.py:77(generate_dcpl)
#      1206    0.001    0.000    0.001    0.000 filters.py:92(rq_tuple)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1022(resize)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:125(reshape)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:1291(ravel)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1380(nonzero)
#    350674    0.142    0.000    0.142    0.000 fromnumeric.py:1462(shape)
#    607067    1.035    0.000    5.847    0.000 fromnumeric.py:1631(sum)
#      1608    0.002    0.000    0.010    0.000 fromnumeric.py:1726(product)
#     38994    0.064    0.000    0.397    0.000 fromnumeric.py:1772(any)
#       606    0.001    0.000    0.009    0.000 fromnumeric.py:1852(all)
#     84351    0.135    0.000    1.030    0.000 fromnumeric.py:2142(amin)
#    103984    0.048    0.000    0.086    0.000 fromnumeric.py:447(swapaxes)
#    337404    3.354    0.000    4.187    0.000 function_base.py:1055(diff)
#     12998    0.273    0.000    0.374    0.000 function_base.py:3427(delete)
#     38994    0.055    0.000    0.161    0.000 getlimits.py:93(__new__)
#       804    0.019    0.000    0.029    0.000 group.py:240(__setitem__)
#       201    0.007    0.000    0.007    0.000 group.py:291(__len__)
#     20301    0.026    0.000    0.070    0.000 group.py:296(__iter__)
#       201    0.001    0.000    0.001    0.000 group.py:31(__init__)
#       201    0.015    0.000    0.022    0.000 group.py:39(create_group)
#       603    0.016    0.000    0.203    0.000 group.py:50(create_dataset)
#         1    0.000    0.000    0.000    0.000 hmac.py:100(_current)
#         1    0.000    0.000    0.000    0.000 hmac.py:119(hexdigest)
#         1    0.000    0.000    0.000    0.000 hmac.py:30(__init__)
#         4    0.000    0.000    0.000    0.000 hmac.py:83(update)
#         1    0.000    0.000    0.000    0.000 hmac.py:88(copy)
#         7    0.000    0.000    0.000    0.000 iostream.py:102(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 iostream.py:123(_flush_from_subprocesses)
#         1    0.000    0.000    0.000    0.000 iostream.py:151(flush)
#         6    0.000    0.000    0.001    0.000 iostream.py:207(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:238(_flush_buffer)
#         1    0.000    0.000    0.000    0.000 iostream.py:247(_new_buffer)
#         8    0.000    0.000    0.000    0.000 iostream.py:93(_is_master_process)
#         1    0.000    0.000    0.000    0.000 iostream.py:96(_is_master_thread)
#         4    0.000    0.000    0.000    0.000 jsonapi.py:31(dumps)
#         1    0.000    0.000    0.000    0.000 jsonutil.py:102(date_default)
#         3    0.000    0.000    0.000    0.000 linalg.py:101(get_linalg_error_extobj)
#         3    0.000    0.000    0.000    0.000 linalg.py:106(_makearray)
#         9    0.000    0.000    0.000    0.000 linalg.py:111(isComplexType)
#         6    0.000    0.000    0.000    0.000 linalg.py:124(_realType)
#         3    0.000    0.000    0.000    0.000 linalg.py:139(_commonType)
#         3    0.000    0.000    0.000    0.000 linalg.py:198(_assertRankAtLeast2)
#         3    0.000    0.000    0.000    0.000 linalg.py:209(_assertNdSquareness)
#         3    0.000    0.000    0.000    0.000 linalg.py:214(_assertFinite)
#         3    0.000    0.000    0.000    0.000 linalg.py:219(_assertNoEmpty2d)
#         3    0.000    0.000    0.000    0.000 linalg.py:820(eigvals)
#         2    0.000    0.000    0.001    0.001 linecache.py:13(getline)
#         2    0.000    0.000    0.001    0.001 linecache.py:33(getlines)
#         2    0.000    0.000    0.001    0.001 linecache.py:72(updatecache)
#     38994    0.739    0.000   25.500    0.001 minpack.py:151(_root_hybr)
#     77988    0.343    0.000    5.672    0.000 minpack.py:18(_check_func)
#    168702    0.601    0.000    2.527    0.000 nanfunctions.py:236(nanmax)
#         3    0.000    0.000    0.000    0.000 numeric.py:141(ones)
#         1    0.000    0.000    0.000    0.000 numeric.py:1910(isscalar)
#    144004    0.117    0.000    0.285    0.000 numeric.py:394(asarray)
#    455001    0.419    0.000    0.995    0.000 numeric.py:464(asanyarray)
#     77988    0.042    0.000    0.081    0.000 numerictypes.py:668(issubclass_)
#     77988    0.116    0.000    0.217    0.000 numerictypes.py:736(issubdtype)
#     77989    0.048    0.000    0.048    0.000 optimize.py:105(__getattr__)
#     38994    0.013    0.000    0.013    0.000 optimize.py:127(_check_unknown_options)
#         1    0.000    0.000    0.000    0.000 poll.py:77(poll)
#         3    0.000    0.000    0.000    0.000 polynomial.py:151(roots)
#         1    0.000    0.000    0.000    0.000 py3compat.py:11(no_code)
#         3    0.000    0.000    0.000    0.000 re.py:138(match)
#         3    0.000    0.000    0.000    0.000 re.py:230(_compile)
#         1    0.000    0.000    0.000    0.000 session.py:195(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:200(extract_header)
#         1    0.000    0.000    0.000    0.000 session.py:441(msg_id)
#         1    0.000    0.000    0.000    0.000 session.py:493(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:496(msg)
#         1    0.000    0.000    0.000    0.000 session.py:515(sign)
#         1    0.000    0.000    0.000    0.000 session.py:530(serialize)
#         1    0.000    0.000    0.000    0.000 session.py:589(send)
#         4    0.000    0.000    0.000    0.000 session.py:84(<lambda>)
#         3    0.000    0.000    0.000    0.000 shape_base.py:230(hstack)
#     25996    0.188    0.000    0.300    0.000 shape_base.py:377(array_split)
#     25996    0.032    0.000    0.335    0.000 shape_base.py:435(split)
#     25996    0.050    0.000    0.401    0.000 shape_base.py:511(hsplit)
#     77997    0.194    0.000    0.374    0.000 shape_base.py:8(atleast_1d)
#         1    0.000    0.000    0.000    0.000 socket.py:232(send_multipart)
#    674808    0.440    0.000    0.654    0.000 sputils.py:65(upcast_char)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:433(_compile_info)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:546(isstring)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:552(_code)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:567(compile)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:64(_compile)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:149(append)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:151(getwidth)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:189(__init__)
#         9    0.000    0.000    0.000    0.000 sre_parse.py:193(__next)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:206(match)
#         8    0.000    0.000    0.000    0.000 sre_parse.py:212(get)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:317(_parse_sub)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:395(_parse)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:67(__init__)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:706(parse)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:92(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:1152(currentThread)
#         1    0.000    0.000    0.000    0.000 threading.py:983(ident)
#        13    0.000    0.000    0.000    0.000 traitlets.py:395(__get__)
#     78001    0.409    0.000    0.756    0.000 twodim_base.py:242(diag)
#     20106    0.008    0.000    0.024    0.000 utf_8.py:15(decode)
#       202    0.005    0.000    0.006    0.000 uuid.py:101(__init__)
#         1    0.000    0.000    0.000    0.000 uuid.py:197(__str__)
#       201    0.000    0.000    0.000    0.000 uuid.py:265(get_hex)
#       202    0.002    0.000    0.011    0.000 uuid.py:579(uuid4)
#         2    0.000    0.000    0.001    0.001 warnings.py:25(_show_warning)
#         2    0.000    0.000    0.001    0.001 warnings.py:40(formatwarning)
#     20106    0.015    0.000    0.015    0.000 {_codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {_sre.compile}
#         6    0.000    0.000    0.000    0.000 {_sre.getlower}
#         2    0.000    0.000    0.001    0.001 {_warnings.warn}
#    162352    0.041    0.000    0.041    0.000 {abs}
#     14204    0.082    0.000    0.082    0.000 {any}
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#     38994    0.007    0.000    0.007    0.000 {callable}
#    674812    0.343    0.000    0.343    0.000 {getattr}
#      1005    0.007    0.000    0.007    0.000 {h5py.h5t.py_create}
#         1    0.000    0.000    0.000    0.000 {hasattr}
#   1476672    0.702    0.000    0.702    0.000 {isinstance}
#    155991    0.059    0.000    0.059    0.000 {issubclass}
#   1390242    0.187    0.000    0.187    0.000 {len}
#         1    0.000    0.000    0.000    0.000 {locals}
#       202    0.001    0.000    0.001    0.000 {map}
#         4    0.000    0.000    0.000    0.000 {max}
#       609    0.001    0.000    0.006    0.000 {method 'all' of 'numpy.ndarray' objects}
#    292047    0.202    0.000    1.261    0.000 {method 'any' of 'numpy.ndarray' objects}
#    156013    0.039    0.000    0.039    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#     84351    0.123    0.000    0.123    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       202    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#     20106    0.013    0.000    0.036    0.000 {method 'decode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         3    0.000    0.000    0.000    0.000 {method 'encode' of 'unicode' objects}
#         2    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#     38994    0.049    0.000    0.049    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#    714412    0.319    0.000    0.319    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#     12998    0.006    0.000    0.006    0.000 {method 'item' of 'numpy.ndarray' objects}
#       202    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#     38994    0.020    0.000    0.020    0.000 {method 'lower' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         3    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#     38994    0.015    0.000    0.015    0.000 {method 'pop' of 'dict' objects}
#    759166    1.325    0.000    1.325    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.001    0.000    0.001    0.000 {method 'readlines' of 'file' objects}
#   1154385    7.146    0.000    7.146    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     97549    0.164    0.000    0.164    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     12998    0.036    0.000    0.036    0.000 {method 'resize' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 {method 'send' of 'zmq.backend.cython.socket.Socket' objects}
#     84351    0.015    0.000    0.015    0.000 {method 'setdefault' of 'dict' objects}
#    674808   10.537    0.000   10.537    0.000 {method 'solve' of 'SuperLU' objects}
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        26    0.000    0.000    0.000    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#    103984    0.038    0.000    0.038    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#     38994    0.044    0.000    0.044    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#       205    0.000    0.000    0.000    0.000 {min}
#    116982    0.245    0.000    0.245    0.000 {numpy.core.multiarray.arange}
#    696959    0.913    0.000    0.913    0.000 {numpy.core.multiarray.array}
#    266056    0.842    0.000    0.842    0.000 {numpy.core.multiarray.concatenate}
#         3    0.000    0.000    0.000    0.000 {numpy.core.multiarray.copyto}
#     13001    0.021    0.000    0.021    0.000 {numpy.core.multiarray.empty}
#     84351    0.565    0.000    0.565    0.000 {numpy.core.multiarray.where}
#   1005869    2.185    0.000    2.185    0.000 {numpy.core.multiarray.zeros}
#         2    0.000    0.000    0.000    0.000 {open}
#         6    0.000    0.000    0.000    0.000 {ord}
#         9    0.000    0.000    0.000    0.000 {posix.getpid}
#         2    0.000    0.000    0.000    0.000 {posix.stat}
#       202    0.003    0.000    0.003    0.000 {posix.urandom}
#     39598    0.026    0.000    0.026    0.000 {range}
#     38994    7.138    0.000   18.714    0.000 {scipy.optimize._minpack._hybrj}
#    253053    1.332    0.000    1.332    0.000 {scipy.sparse._sparsetools.csc_matvecs}
#    421755    1.135    0.000    1.135    0.000 {scipy.sparse._sparsetools.csc_matvec}
#         1    0.000    0.000    0.000    0.000 {thread.get_ident}
#         6    0.000    0.000    0.000    0.000 {time.time}
#     97349    0.088    0.000    0.088    0.000 {zip}
#         1    0.000    0.000    0.000    0.000 {zmq.backend.cython._poll.zmq_poll}
# /usr/local/lib/python2.7/site-packages/scipy/optimize/minpack.py:237: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# emigrate/equilibration_schemes/Multiroot.py:62: UserWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(roots.message)

# %% [markdown]
# The solution resides in an Electromigration inside the Migrate object. Here, this object is solver.electromigration. Electromigration objects are iterable, so we can plot each concentration profile from them. In this case, that's somewhat unhelpful since there are so many solutions.

# %%
figure()
for frame in solver.frame_series:
    for ion_concentration in frame.concentrations:
        plot(frame.nodes, ion_concentration, '-')

xlabel('x (mm)')
ylabel('concentration (M)')
ylim([0, .2])
show()

# %% [markdown]
# However, the electromigration essentially acts as a list of frames, so we can also just plot an individual frame.

# %%
figure()
frame = solver.frame_series[100]
for ion_concentration in frame.concentrations:
    plot(frame.nodes, ion_concentration, '-')

xlabel('x (m)')
ylabel('concentration (M)')
xlim([min(system.nodes), max(system.nodes)])
show()

figure()
plot(frame.nodes, frame.pH, '-')
xlabel('x (m)')
ylabel('pH')
xlim([min(system.nodes), max(system.nodes)])
show()

# %% [markdown]
# Options for solving
# -------------------

# %% [markdown]
# ### Modules
# The solver loads two types of modules:
# - The flux module.  This module defines the flux of ions through the domain.
# - The equilibrium module. This module defines the mobility, diffusivity, and molar conductivity of ions. These values are used by the flux module.
#
# By default, the flux module called is the compact solver with no adaptive grid.
# The equilibrium solver called is the fixed pH solver.

# %% [markdown]
# ### Reference Frame
# You can set the reference frame of the solution before solving the problem.

# %%
solutions = [ionize.Solution(['acetic acid', 'b-alanine'], [.02, .012]),
             ionize.Solution(['acetic acid', 'pyridine', 'aniline'], [.02, .009/2, .011/2]), 
             ionize.Solution(['acetic acid', 'sodium'], [.02, .018]), 
            ]
system = emigrate.Frame(dict(lengths=[.01, .004, .01],
                         n_nodes=100,
                         interface_length=.0005,
                         solutions=solutions,
                         current_density=500,
                         domain_mode='left', 
                         ))
for i in range(len(system.ions)):
    plot(system.nodes, system.concentrations[i,:])
xlabel('x (m)')
ylabel('concentration (M)')
show()

# %%
solver = emigrate.Solver(system, filename='examples/example_2.hdf5', precondition=True, flux_mode='slip')
tmax = 80
dt = 1
ode_solver = 'dopri5'
profile = False
solver.set_reference_frame(ionize.load_ion('acetic acid'), 'right')

epoch = time.time()
solver.solve(dt, tmax, method=ode_solver)
print 'Solved in {:.2f} seconds.'.format(time.time()-epoch)
# Out:
# Solving...
# Solved.
# Solved in 102.06 seconds.
# emigrate/flux_schemes/SLIP.py:114: RuntimeWarning: invalid value encountered in divide
#   cost = deriv / np.nanmax(deriv, 1)[:, np.newaxis]

# %%
figure()
electrolyte = solver.frame_series[80]
for ion_concentration in electrolyte.concentrations:
    plot(electrolyte.nodes, ion_concentration, '-')

xlabel('x (m)')
ylabel('concentration (M)')
xlim([min(system.nodes), max(system.nodes)])
ylim([0, .05])
show()

# %% [markdown]
# Saving to Disk
# --------------
# The default method for saving is to write to an HDF5 binary file. If a filename is specified when initializing the Migration, then the each frame will be saved to that HDF5 file as soon as it is computed. We can re-open these HDF5 files and get solutions on demand.
#
# These HDF5 files can also be opened with the Emigrate application.

# %%
# Work with HDF5 file.

# %% [markdown]
# If JSON objects are desired, both electromigrations and electrolytes can be written in JSON format. However, beware when doing this for the electromigrations, as the file size can be very large.

# %%
# solver.electromigration.write_json('tutorial_example_5.json')

# %% [markdown]
# Solutions can then be reloaded using the Electromigration class. Currently, they lose all ion information except name during this process.

# %%
# solution_reloaded = emigrate.Electromigration([]).load_json('tutorial_example.json')

# print solution_reloaded.ions
# for t, electrolyte in solution_reloaded.electrolytes.items():
#     for ion_concentration in electrolyte.concentrations:
#             plot(electrolyte.nodes*1000, ion_concentration, '-')
# xlabel('x (mm)')
# ylabel('concentration (M)')
# show()

# %% [markdown]
# Instead of saving to file, json objects can simply be generated as text using the "serialize" command, and those objects can be deserialized to return the original object.

# %% [markdown]
# Countermigrating Waves
# ---------------------

# %%
solutions = [ionize.Solution(['caproic acid', 'tris'], [.0075, .015]),
             ionize.Solution(['hydrochloric acid', 'tris', 'alexa fluor 488', 'rhodamine 6g'], 
                             [.005, .01, .0001, .0001]),
             ionize.Solution(['hydrochloric acid', 'bis-tris'], [.0075, .015])
            ]

system = emigrate.Frame(dict(lengths=[0.01]*len(solutions),
                         n_nodes=200,
                         interface_length=.0005,
                         solutions=solutions,
#                          voltage= -50., 
                         current_density=-200,
                         domain_mode='left'
                         ))
for i in range(len(system.ions)):
    plot(system.nodes, system.concentrations[i,:])
xlabel('x (m)')
ylabel('concentration (M)')
show()

# %%
# solver.electromigration.hdf5.close()
solver = emigrate.Solver(system, filename='examples/countermigrating.hdf5', precondition=True, flux_mode='slip')
tmax = 100
dt = .1
ode_solver = 'dopri5'
profile = False

if profile:
    cProfile.run("solver.solve(tmax, dt, method=ode_solver)")
else:
    epoch = time.time()
    solver.solve(dt, tmax, method=ode_solver)
    print 'Solved in {} seconds.'.format(time.time()-epoch)
# Out:
# Solving...
# Solved.
# Solved in 146.322132111 seconds.

# %%
for frame in solver.frame_series:
        for ion_concentration in frame.concentrations:
            plot(frame.nodes*1000, ion_concentration, '-')
xlabel('x (mm)')
ylabel('concentration (M)')
show()

figure()
for frame in solver.frame_series:
        plot(frame.nodes*1000, frame.pH, '-')
xlabel('x (mm)')
ylabel('pH')
show()

# %% [markdown]
# Example 3
# ----------

# %% [markdown]
# ## Non-focusing Example

# %%
separation_buffer = ionize.Solution(['tris', 'hydrochloric acid'], [.01, .005])
solutions = [separation_buffer,
             separation_buffer + ionize.Solution(['alexa fluor 488'], [.001]), 
             separation_buffer]
system = emigrate.Frame(dict(lengths=[.01, .001, .089],
                         n_nodes=100,
                         interface_length=.0005,
                         solutions=solutions,
                         current_density=-500,
                         domain_mode='left', 
                         ))
for i in range(len(system.ions)):
    plot(system.nodes, system.concentrations[i,:])
xlabel('x (m)')
ylabel('concentration (M)')
show()

# %%
solver = emigrate.Solver(system, filename='examples/example_4.hdf5', precondition=False, flux_mode='slip')
tmax = 200
dt = 1
ode_solver = 'dopri5'
profile = False
# solver.set_reference_frame(ionize.load_ion('acetic acid'), 'right')

epoch = time.time()
solver.solve(dt, tmax, method=ode_solver)
print 'Solved in {:.2f} seconds.'.format(time.time()-epoch)
# Out:
# Solving...
# Solved.
# Solved in 23.74 seconds.

# %% [markdown]
# Example 4
# ----------

# %%
water = ionize.Solution()

solutions = [ionize.Solution(['tris', 'hydrochloric acid'], [.01, .01]),
             ionize.Solution(['hydrochloric acid'], [.01])]
system = emigrate.Frame(dict(lengths=[.01, .01],
                         n_nodes=100,
                         interface_length=.0005,
                         solutions=solutions,
                         current_density=-50,
                         domain_mode='left', 
                         ))
# for i in range(len(system.ions)):
#     plot(system.nodes, system.concentrations[i,:])
# xlabel('x (m)')
# ylabel('concentration (M)')
# show()

# %%
solver = emigrate.Solver(system, filename='examples/example_5a.hdf5', precondition=True, flux_mode='slip')
tmax = 200
dt = 1
ode_solver = 'dopri5'
profile = False
# solver.set_reference_frame(ionize.load_ion('acetic acid'), 'right')

epoch = time.time()
solver.solve(dt, tmax, method=ode_solver)
print 'Solved in {:.2f} seconds.'.format(time.time()-epoch)
# Out:
# Solving...
# Solved.
# Solved in 593.11 seconds.
